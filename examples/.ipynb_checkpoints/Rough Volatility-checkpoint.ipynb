# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Visualization-dataset" data-toc-modified-id="Visualization-dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Visualization dataset</a></span></li><li><span><a href="#Set-up-experiment-parameters" data-toc-modified-id="Set-up-experiment-parameters-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Set up experiment parameters</a></span></li><li><span><a href="#RBF-RBF" data-toc-modified-id="RBF-RBF-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>RBF-RBF</a></span></li><li><span><a href="#kerES" data-toc-modified-id="kerES-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>kerES</a></span></li><li><span><a href="#linSES" data-toc-modified-id="linSES-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>linSES</a></span></li><li><span><a href="#Neural-Net-approach-(DeepSets)" data-toc-modified-id="Neural-Net-approach-(DeepSets)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Neural Net approach (DeepSets)</a></span></li><li><span><a href="#DeepSets-adapted-to-sequential-data:-DeepSet-LSTM" data-toc-modified-id="DeepSets-adapted-to-sequential-data:-DeepSet-LSTM-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>DeepSets adapted to sequential data: DeepSet-LSTM</a></span></li><li><span><a href="#Lead-lag-transform" data-toc-modified-id="Lead-lag-transform-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Lead-lag transform</a></span></li></ul></div>

# %%
# !pip install fbm

# %%
import sys
sys.path.append('../src')

import numpy as np
import torch
import pandas as pd
import importlib
from tqdm import tqdm as tqdm
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

import utils_roughvol

import RBF_RBF
import RBF_TKA
import RBF_Matern
import kerES
import KES
import linSES
import sklearn_transformers
import deep_sets


import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (16, 4),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)
import pickle

# %% [markdown]
# We assume that prices follow the following fractional OU process
#
# $$dX_t =  -\alpha(X_t - \mu) + \nu dW^H_t$$
#
# where $W^H_t$ is fBM with H<0.5. This RDE has an explicit solution
#
# $$X_t = \nu \int_{-\infty}^t e^{-\alpha(t-s)}dW_s^H + \mu$$
#
# The Rough Fractional Stochastic Volatility (RFSV) model is defined in https://arxiv.org/pdf/1410.3394.pdf as follows
#
# $$\sigma_t = e^{X_t}$$

# %% [markdown]
# # Visualization dataset

# %%
tot = 15
l = 300

a1 = 0.00001
a2 = 0.001
a3 = 0.1

list_df_prices = []
list_df_vols = []

for a in [a1, a2, a3]:
    
    df = pd.DataFrame(data=[utils_roughvol.fOU_generator(a,length=l) for k in range(tot)], 
                      columns=range(l+1)).T
    list_df_prices.append(df)

    list_df_vols.append(df.apply(lambda x: np.exp(x)))

# %%
custom_lines = [Line2D([0], [0], color='blue', lw=4), Line2D([0], [0], color='red', lw=4)]

fig, ax = plt.subplots(1, 3)

k=0
for df_p, df_v, a, axx in zip(list_df_prices, list_df_vols, [a1,a2,a3], ax.flatten()):
    if a<1e-4:
        title = 'a = {:.5f}'.format(a)
    else:
        title = 'a = {}'.format(a)
    df_p.plot(grid=True, title=title, legend=False, c='blue', alpha=0.3, ax=axx)
    df_v.plot(grid=True, legend=False, c='red', alpha=0.3, ax=axx)
    if k==0:
        axx.legend(custom_lines, ['fOU prices (H=0.2)', 'rough volatility'])
    k+=1

#plt.savefig('../pictures/fOU_rough_vol.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Set up experiment parameters

# %%
M = 50
N = 20 # change to 20, 50, 100 to reproduce the experiments
length = 300

max_T = 1e0
min_T = 1e-6
np.random.seed(0)
y = np.array((max_T-min_T)*np.random.rand(M)+min_T)

# %%
X = []
    
for a in tqdm(y):
    intermediate = []
    for n in range(N):
        path = np.exp(utils_roughvol.fOU_generator(a, length=length)).reshape(-1,1)
        intermediate.append(path)
    X.append(intermediate)
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  7.53it/s]

# %%
def mse(results):
    mse_vec = np.zeros(len(results))
 
    for i in range(len(results)):
        pred = results[i]['pred']
        true = results[i]['true']
        mse_vec[i]=np.mean((pred-true)**2)
    return np.mean(mse_vec), np.std(mse_vec)

def mape(results):
    mape_vec = np.zeros(len(results))
 
    for i in range(len(results)):
        pred = results[i]['pred']
        true = results[i]['true']
        mape_vec[i]=np.mean(np.abs((true - pred) / true))*100 
    return np.mean(mape_vec), np.std(mape_vec)

# %% [markdown]
# # RBF-RBF

# %%
m_mse, std_mse, results_RBF = RBF_RBF.model(X,y,at=True,mode='krr',NUM_TRIALS=5,  cv=3)  # add-time (at) or lead-lag (ll) do not improve the results
# Out:
# 100%|██████████| 5/5 [00:13<00:00,  2.67s/it]

# %%
print('mse',mse(results_RBF))
print('mape',mape(results_RBF))
# Out:
# mse (0.04076469585789844, 0.008570818287395478)
# mape (36.84091652915099, 7.903646993625888)

# %% [markdown]
# # RBF-Matern

# %%
m_mse, std_mse, results_Matern =RBF_Matern.model(X,y,at=True,mode='krr',NUM_TRIALS=5,  cv=3)  # add-time (at) or lead-lag (ll) do not improve the results
# Out:
# Fitting 3 folds for each of 125 candidates, totalling 375 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 64 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 375 out of 375 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 64 concurrent workers.
# Fitting 3 folds for each of 125 candidates, totalling 375 fits
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 248 out of 375 | elapsed:    0.8s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 375 out of 375 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 64 concurrent workers.
# Fitting 3 folds for each of 125 candidates, totalling 375 fits
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 248 out of 375 | elapsed:    0.9s remaining:    0.5s
# ...

# %%
print('mse',mse(results_Matern))
print('mape',mape(results_Matern))
# Out:
# mse (0.048978414302839404, 0.012375542853972544)
# mape (40.274313311878956, 10.598729980699877)

# %% [markdown]
# # RBF-GA

# %%
importlib.reload(RBF_TKA)
# Out:
# <module 'RBF_TKA' from '../src/RBF_TKA.py'>

# %%
m_mse, std_mse, results_GA =RBF_TKA.model(X,y,at=True,mode='krr',NUM_TRIALS=5,  cv=3,lambdas=[0.01])  # add-time (at) or lead-lag (ll) do not improve the result
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 64 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 689 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 3235 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 12288 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 25600 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 40960 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 58368 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 77824 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 99328 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 122880 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 148480 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 176128 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 205824 tasks      | elapsed:   31.9s
# ...

# %%
print('mse',mse(results_GA))
print('mape',mape(results_GA))
# Out:
# mse (0.002244730525552418, 0.0002341698906860728)
# mape (8.830757374304483, 2.7358680142671545)

# %% [markdown]
# # KES

# %%
importlib.reload(KES)
# Out:
# <module 'KES' from '../src/KES.py'>

# %%
m_mse, std_mse, results_KES = KES.model(X, y,  ll=[0], at=True, scales=[0.3], mode='krr', NUM_TRIALS=5,  cv=3)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s][Parallel(n_jobs=-1)]: Using backend LokyBackend with 64 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 1024 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 1275 out of 1275 | elapsed:  2.8min finished
# ...
#  20%|██        | 1/5 [00:00<00:01,  3.72it/s]
# best truncation level (cv on the train set):  0.3
#  40%|████      | 2/5 [00:00<00:00,  3.78it/s]
# best truncation level (cv on the train set):  0.3
#  60%|██████    | 3/5 [00:00<00:00,  3.81it/s]
# best truncation level (cv on the train set):  0.3
#  80%|████████  | 4/5 [00:01<00:00,  3.84it/s]
# best truncation level (cv on the train set):  0.3
# 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# best truncation level (cv on the train set):  0.3
# ...

# %%
print('mse',mse(results_KES))
print('mape',mape(results_KES))
# Out:
# mse (0.0009082685287232596, 0.00035859023014810245)
# mape (5.063253923862871, 1.045226334871053)

# %% [markdown]
# # linSES

# %%
m_mse, std_mse, results_SES = linSES.model([[item for item in x] for x in X], y, depths1=[2,3,4], depth2=1, ll=[0], at=True, NUM_TRIALS=5, cv=3)
# Out:
#  20%|██        | 1/5 [00:01<00:04,  1.14s/it]
# best truncation level (cv on train set):  4
#  40%|████      | 2/5 [00:02<00:03,  1.13s/it]
# best truncation level (cv on train set):  4
#  60%|██████    | 3/5 [00:03<00:02,  1.12s/it]
# best truncation level (cv on train set):  4
#  80%|████████  | 4/5 [00:04<00:01,  1.12s/it]
# best truncation level (cv on train set):  4
# 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# best truncation level (cv on train set):  4

# %%
print('mse',mse(results_SES))
print('mape',mape(results_SES))
# Out:
# mse (0.0015276175175326988, 0.00047421792510715356)
# mape (6.163641917308592, 1.239683803753236)

# %% [markdown]
# # Save results

# %%
mse(results_RBF)
# Out:
# (0.05701948880770576, 0.014090280973160793)

# %%
results = {'rbf':results_RBF, 'Matern':results_Matern, 'GA':results_GA, 'KER':results_KES, 'SES':results_SES}
pickle.dump(results,open('finance_20_length_100.obj','wb'))

# %% [markdown]
# # Neural Net approach (DeepSets)
#
# https://arxiv.org/pdf/1703.06114.pdf

# %%
importlib.reload(deep_sets)
# Out:
# <module 'deep_sets' from '../src/deep_sets.py'>

# %%
batch_size = 20
nb_epoch = 1000

# %%
MSEs = []

for j in range(5):
        
    X_train, X_test, y_train, y_test = train_test_split([[x.reshape(-1) for x in xx] for xx in X], y, test_size=0.2, random_state=None)
    
    train = deep_sets.DataIterator(torch.Tensor(X_train), torch.Tensor(y_train), batch_size, shuffle=True)
    test  = deep_sets.DataIterator(torch.Tensor(X_test), torch.Tensor(y_test), 1)

    model = deep_sets.DeepSet

    t = deep_sets.Trainer(train.d, model, nb_epoch)

    t.fit(train)
    
    MSEs.append(t.evaluate(test))
    
print(np.mean(MSEs), np.std(MSEs))
# Out:
# Train loss: 0.075300
# Train loss: 0.004569
# Train loss: 0.003281
# Train loss: 0.000198
# Train loss: 0.000110
# Train loss: 0.096582
# Train loss: 0.002577
# Train loss: 0.000144
# Train loss: 0.000004
# Train loss: 0.000317
# Train loss: 0.257079
# Train loss: 0.002867
# Train loss: 0.001315
# Train loss: 0.000208
# Train loss: 0.000304
# Train loss: 0.109833
# Train loss: 0.003918
# Train loss: 0.000908
# Train loss: 0.000000
# Train loss: 0.000000
# Train loss: 0.052589
# Train loss: 0.000135
# Train loss: 0.000002
# Train loss: 0.000001
# Train loss: 0.000162
# 0.09553812757882496 0.030165761662112846

# %% [markdown]
# # DeepSets adapted to sequential data: DeepSet-LSTM

# %%
MSEs = []

for j in range(5):
    
    X = []
    for a in y:
        intermediate = []
        for n in range(N):
            intermediate.append(np.exp(utils_roughvol.fOU_generator(a))[:,None])
        X.append(intermediate)
        
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)
    
    train = deep_sets.DataIterator(torch.Tensor(X_train), torch.Tensor(y_train), batch_size, shuffle=True)
    test  = deep_sets.DataIterator(torch.Tensor(X_test), torch.Tensor(y_test), 1)

    model = deep_sets.DeepSetLSTM

    t = deep_sets.Trainer(train.d, model, nb_epoch)

    t.fit(train)
    
    MSEs.append(t.evaluate(test))
    
print(np.mean(MSEs), np.std(MSEs))
# Out:
# Train loss: 14.156323
# Train loss: 0.006026
# Train loss: 0.004821
# Train loss: 0.003121
# Train loss: 0.002109
# Train loss: 4.484265
# Train loss: 0.004233
# Train loss: 0.000391
# Train loss: 0.000001
# Train loss: 0.000000
# Train loss: 0.342505
# Train loss: 0.001452
# Train loss: 0.000001
# Train loss: 0.000000
# Train loss: 0.000000
# Train loss: 0.100298
# Train loss: 0.001007
# Train loss: 0.000270
# Train loss: 0.000046
# Train loss: 0.000028
# Train loss: 0.074023
# Train loss: 0.000061
# Train loss: 0.000004
# Train loss: 0.000146
# Train loss: 0.000146
# 0.11570959871275703 0.04315897767986933

# %% [markdown]
# # Lead-lag transform

# %%
X = np.array([1,5,3,6])[:,None]
a = LeadLag([0]).fit_transform([[X]])

# %%
plt.plot(np.arange(1,8),a[0][0][:,0],color='blue',label='lead')
plt.plot(np.arange(1,8),a[0][0][:,1],color='red',label='lag')
plt.plot(np.arange(1,5),X[:,0],color='orange',label='original')
plt.legend()
plt.show()
